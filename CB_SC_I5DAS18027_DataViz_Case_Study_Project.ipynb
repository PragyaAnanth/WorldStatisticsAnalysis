# %% [markdown]
# <a href="https://colab.research.google.com/github/PragyaAnanth/WorldStatisticsAnalysis/blob/main/CB_SC_I5DAS18027_DataViz_Case_Study_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **18CS312 - Data Visualization**
# # **Analysis of World Statistics — A Case Study Project**
#
# **Faculty:** <br>
# Ms. Archanaa R <br>
# Assistent Professor <br>
# Department of Computer Science and Engineering <br>
# Amrita School of Engineering Coimbatore <br>
# <br>
#
# **Student Details:**
# ### **Pragya Ananth**
# ### **CB.SC.I5DAS18027**
# Integrated M.Sc. Data Science <br>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('/content/drive/MyDrive/18CSC312 - Data Visualization/Project Case Study/data.csv')
df.head()
# Out:
#   Country Name  ... Surface area (sq. km)
# 0  Afghanistan  ...                   NaN
# 1  Afghanistan  ...              652860.0
# 2  Afghanistan  ...              652860.0
# 3  Afghanistan  ...              652860.0
# 4  Afghanistan  ...              652860.0
#
# [5 rows x 55 columns]

# %%
df.shape
# Out:
# (16104, 55)

# %%
df['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Arab World', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'year',
#        'Access to electricity (% of population)',
#        'Access to electricity, rural (% of rural population)',
#        'Agricultural irrigated land (% of total agricultural land)',
#        'Agricultural land (% of land area)', 'Agricultural land (sq. km)',
#        'Agricultural machinery, tractors',
#        'Agricultural machinery, tractors per 100 sq. km of arable land',
#        'Agricultural methane emissions (% of total)',
#        'Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#        'Agricultural nitrous oxide emissions (% of total)',
#        'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#        'Agricultural raw materials exports (% of merchandise exports)',
#        'Agricultural raw materials imports (% of merchandise imports)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
# ...

# %%
df.isnull().sum()
# Out:
# Country Name                                                                                      0
# Country Code                                                                                      0
# year                                                                                              0
# Access to electricity (% of population)                                                        9930
# Access to electricity, rural (% of rural population)                                          10145
# Agricultural irrigated land (% of total agricultural land)                                    15248
# Agricultural land (% of land area)                                                             3049
# Agricultural land (sq. km)                                                                     2872
# Agricultural machinery, tractors                                                               8321
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16104 entries, 0 to 16103
# Data columns (total 55 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   Country Name                                                                                16104 non-null  object
#  1   Country Code                                                                                16104 non-null  object
#  2   year                                                                                        16104 non-null  int64
#  3   Access to electricity (% of population)                                                     6174 non-null   float64
#  4   Access to electricity, rural (% of rural population)                                        5959 non-null   float64
# ...

# %%
df.fillna(value=0,inplace=True)

# %%
df.head()
# Out:
#   Country Name  ... Surface area (sq. km)
# 0  Afghanistan  ...                   0.0
# 1  Afghanistan  ...              652860.0
# 2  Afghanistan  ...              652860.0
# 3  Afghanistan  ...              652860.0
# 4  Afghanistan  ...              652860.0
#
# [5 rows x 55 columns]

# %%
df.isnull().sum()
# Out:
# Country Name                                                                                  0
# Country Code                                                                                  0
# year                                                                                          0
# Access to electricity (% of population)                                                       0
# Access to electricity, rural (% of rural population)                                          0
# Agricultural irrigated land (% of total agricultural land)                                    0
# Agricultural land (% of land area)                                                            0
# Agricultural land (sq. km)                                                                    0
# Agricultural machinery, tractors                                                              0
# Agricultural machinery, tractors per 100 sq. km of arable land                                0
# ...

# %%
#df.to_csv('/content/drive/MyDrive/18CSC312 - Data Visualization/Project Case Study/data_clean.csv')

# %%
df1=df.loc[(df["Country Name"]=="Brazil") | (df["Country Name"]=="India")]
df1
# Out:
#      Country Name  ... Surface area (sq. km)
# 1647       Brazil  ...          0.000000e+00
# 1648       Brazil  ...          8.515770e+06
# 1649       Brazil  ...          8.515770e+06
# 1650       Brazil  ...          8.515770e+06
# 1651       Brazil  ...          8.515770e+06
# ...           ...  ...                   ...
# 6705        India  ...          3.287259e+06
# 6706        India  ...          3.287259e+06
# 6707        India  ...          3.287259e+06
# 6708        India  ...          0.000000e+00
# 6709        India  ...          0.000000e+00
#
# [122 rows x 55 columns]

# %%
df1["Country Name2"]=df1["Country Name"].map({"India":1,"Brazil":2})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1
# Out:
#      Country Name Country Code  ...  Surface area (sq. km)  Country Name2
# 1647       Brazil          BRA  ...           0.000000e+00              2
# 1648       Brazil          BRA  ...           8.515770e+06              2
# 1649       Brazil          BRA  ...           8.515770e+06              2
# 1650       Brazil          BRA  ...           8.515770e+06              2
# 1651       Brazil          BRA  ...           8.515770e+06              2
# ...           ...          ...  ...                    ...            ...
# 6705        India          IND  ...           3.287259e+06              1
# 6706        India          IND  ...           3.287259e+06              1
# 6707        India          IND  ...           3.287259e+06              1
# 6708        India          IND  ...           0.000000e+00              1
# 6709        India          IND  ...           0.000000e+00              1
#
# [122 rows x 56 columns]

# %%
dims=["Agriculture, forestry, and fishing, value added (% of GDP)",
      "Agricultural raw materials exports (% of merchandise exports)",
    'Agricultural raw materials imports (% of merchandise imports)']

# %%
fig=px.parallel_coordinates(df1,color="Country Name2",labels={"Country Name2":"Country"},dimensions=dims,
                            color_continuous_scale=px.colors.diverging.Tealrose)
                             #color_continuous_midpoint=2)
fig.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="01a61e9c-b8ab-474c-9516-32a6d1025584" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("01a61e9c-b8ab-474c-9516-32a6d1025584")) {
#                     Plotly.newPlot(
#                         '01a61e9c-b8ab-474c-9516-32a6d1025584',
# ...

# %%
df11=df.loc[df["Country Name"]=="India"]

# %%
dims1=[  'Access to electricity (% of population)',
       'Access to electricity, rural (% of rural population)',
       'Agricultural machinery, tractors']

# %%
fig1 = px.scatter_matrix(df11,dimensions=dims1,color="year")
fig1.update_yaxes(automargin=True,tickangle=45)
fig1.update_xaxes(automargin=True,tickangle=45)
fig1.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87e4e153-0e14-4961-94f0-62c598ddc8e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87e4e153-0e14-4961-94f0-62c598ddc8e1")) {
#                     Plotly.newPlot(
#                         '87e4e153-0e14-4961-94f0-62c598ddc8e1',
# ...
